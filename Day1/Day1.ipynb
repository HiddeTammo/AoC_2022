# %% [markdown]
# # Part 1

# %%
#Input
f = open('input.txt', 'r')
x = f.read().splitlines()
x
# Out:
# ['5686',
#  '2211',
#  '1513',
#  '7036',
#  '5196',
#  '10274',
#  '2967',
#  '2551',
#  '',
#  '5942',
#  '5827',
#  '2514',
#  '4024',
#  '',
#  '9857',
#  '13173',
#  '13071',
#  '17540',
#  '',
#  '8264',
#  '2725',
#  '6163',
#  '3589',
#  '4223',
#  '8568',
#  '3009',
#  '8662',
#  '1376',
#  '',
#  '1270',
#  '5911',
#  '6619',
#  '4174',
#  '1153',
#  '7989',
#  '2435',
#  '3577',
#  '1086',
#  '3233',
#  '',
#  '16008',
#  '16955',
#  '13004',
#  '',
#  '5135',
#  '2622',
#  '7433',
#  '2508',
#  '6498',
#  '6702',
#  '4321',
#  '3999',
#  '5778',
#  '2692',
#  '1523',
#  '',
#  '7310',
#  '1841',
#  '2040',
#  '4938',
#  '6186',
#  '1555',
#  '6107',
#  '2880',
#  '4305',
#  '1270',
#  '8060',
#  '',
#  '8727',
#  '5727',
#  '12263',
#  '14610',
#  '9171',
#  '',
#  '42938',
#  '',
#  '1860',
#  '5190',
#  '3635',
#  '1963',
#  '4026',
#  '4287',
#  '3410',
#  '1670',
#  '6451',
#  '3981',
#  '1281',
#  '1225',
#  '6461',
#  '3709',
#  '',
#  '5058',
#  '5947',
#  '1528',
# ...

# %%
#Parameters
elfNum = 0
maxElf = 0
l = len(x)
print(l)
maxCal = 0
cal = 0

for i in range(l):
    
    #When blank compare current and max elf
    if x[i] == '':
        
        elfNum += 1
        print(cal)
        if maxCal < cal:
            maxElf = elfNum
            maxCal = cal
            print("The elf with the most calories is elf "+str(maxElf)+" with "+str(maxCal)+" calories")
        cal = 0
    #If a value rasie calories
    else:
        cal += int(x[i])
    
    #Last elf calorie input
    if i == l-1:
        print("This is used")
        print(cal)
        elfNum += 1
        if maxCal < cal:
            
            maxElf = elfNum
            maxCal = cal
            print("The elf with the most calories is elf "+str(maxElf)+" with "+str(maxCal)+" calories")
        cal = 0

        
print("The elf with the most calories is elf "+str(maxElf)+" with "+str(maxCal)+" calories")
# Out:
# 2255
# 37434
# The elf with the most calories is elf 1 with 37434 calories
# 18307
# 53641
# The elf with the most calories is elf 3 with 53641 calories
# 46579
# 37447
# 45967
# 49211
# 46492
# 50498
# 42938
# 49149
# 47563
# 53619
# 45892
# 57499
# The elf with the most calories is elf 15 with 57499 calories
# 49758
# 38337
# 45061
# 57399
# 16336
# 52925
# 41084
# 61840
# The elf with the most calories is elf 23 with 61840 calories
# 47530
# 36103
# 38231
# 41280
# 58959
# 47645
# 49996
# 41496
# 61565
# 52901
# 48500
# 41396
# 60366
# 57084
# 59852
# 52733
# 47027
# 39251
# 45064
# 61916
# The elf with the most calories is elf 43 with 61916 calories
# 42391
# 36957
# 41439
# 57432
# 43715
# 22043
# 58199
# 37393
# 61083
# 52483
# 59670
# 40493
# 39589
# 46482
# 40576
# 38270
# 54672
# 41730
# 57825
# 56383
# 46612
# 63080
# The elf with the most calories is elf 65 with 63080 calories
# 50017
# 40927
# 49989
# 51109
# 50325
# 51072
# 45410
# 62588
# 40408
# 48975
# 56720
# 39918
# ...

# %% [markdown]
# # Part 2

# %%
#Parameters
l = len(x)
print(l)

#calorie ranking
cal1 = 0
cal2 = 0
cal3 = 0 
cal  = 0

#Insert multiple if statements for each range

for i in range(l):
    
    #When blank compare current and max elf
    if x[i] == '':
        #Higher than highest rank
        if cal1 < cal:
            cal3 = cal2
            cal2 = cal1
            cal1 = cal
        elif cal2 < cal:
            cal3 = cal2
            cal2 = cal
        elif cal3 < cal:
            cal3 = cal
        cal = 0
    #If a value rasie calories
    else:
        cal += int(x[i])
    
    #Last elf calorie input
    if i == l-1:
        print("This is used")
        #Higher than highest rank
        if cal1 < cal:
            cal3 = cal2
            cal2 = cal1
            cal1 = cal
        #Higher than rank 2
        elif cal2 < cal:
            cal3 = cal2
            cal2 = cal
        #Higher than rank 3
        elif cal3 < cal:
            cal3 = cal
        cal = 0

top3 = cal1 + cal2 + cal3        
print("The most calories of top 3 elves is "+str(top3))
# Out:
# 2255
# This is used
# The most calories of top 3 elves is 198551
